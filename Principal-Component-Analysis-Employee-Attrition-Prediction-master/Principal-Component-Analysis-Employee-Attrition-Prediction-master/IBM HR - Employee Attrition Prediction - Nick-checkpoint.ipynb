# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing and Checking the shape of the dataframe

df_hr = pd.read_csv('IBM HR.csv')
df_hr.shape
# Out:
# (1470, 35)

# %%
df_hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Checking data types
df_hr.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# Data Cleaning

# %%
# Checking whether we have any missing values
df_hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# The data has no missing values

# %%
# Dropping EmployeeNumber
# Replacing Yes/No in the target variable (Attrition) with 1/0

df_hr.drop('EmployeeNumber', axis=1, inplace=True)
df_hr['Attrition'] = df_hr['Attrition'].map({'No':0, 'Yes':1})

# %%
df_hr.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1470.0              1470.000000  1470.000000     1470.000000
# mean             1.0                 2.721769    65.891156        2.729932
# ...

# %%
# It can be seen above that EmployeeCount and StandardHours are constants
# Hence, dropping EmployeeCount and StandardHours

df_hr.drop(['EmployeeCount','StandardHours'], axis=1, inplace=True)

# %%
# Exploratory Data Analysis

# %%
# Plot showing employee attrition

ax = sns.countplot(df_hr['Attrition'])

ax.yaxis.grid()

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(False)
ax.spines['left'].set_linewidth(False)

plt.show()

# %%
# It can be observed that about employees who discontinued are about 1/6th of those who are continuing

# %%
# Attrition by Business Travel

df_attrition_y = df_hr[df_hr['Attrition']==1]
df_attrition_n = df_hr[df_hr['Attrition']==0]

fig, ax = plt.subplots(1,2)

fig.subplots_adjust(wspace=1)


sns.countplot(df_attrition_n['BusinessTravel'], ax=ax[0])
ax[0].set_title('Attrition = No')
plt.setp(ax[0].get_xticklabels(), rotation=90, ha="center")

sns.countplot(df_attrition_y['BusinessTravel'], ax=ax[1])
ax[1].set_title('Attrition = Yes')
plt.setp(ax[1].get_xticklabels(), rotation=90, ha="center")
# Out:
# [None, None, None, None, None, None]

# %%
# It appears that among the employees who discontinued, frequent travel is comparatively a larger portion of the group

# %%
# Distribution of Monthly Income


tenure = sns.FacetGrid(data=df_hr, col='Attrition', height=4, aspect=2)
tenure.map(plt.hist, 'MonthlyIncome', bins=150)


tenure.set(xlabel='Daily Rate', ylabel='No. of Employees')
plt.show()

# %%
# We can see that among the employees who discontinued, the higher end of Monthly Income is comparatively sparse
# We can use KDE plot to represent this information more clearly

# %%
# Monthly Rate distribution using Kernel Density Estimate (KDE) Plot

ax = sns.kdeplot(df_hr.MonthlyIncome[(df_hr["Attrition"] == 0) ],
                color="Green", shade = True)
ax = sns.kdeplot(df_hr.MonthlyIncome[(df_hr["Attrition"] == 1) ],
                ax =ax, color="Red", shade= True)
ax.legend(["Attrition = No","Attrition = Yes"], loc='upper right')
ax.set_ylabel('Density')
ax.set_xlabel('Monthly Income')
ax.set_title('Distribution of Monthly Income by Attrition')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(False)
ax.spines['left'].set_linewidth(False)


# figure size in inches
sns.set(rc={'figure.figsize':(7,5)})

# %%
# Distribution of 'Attrition = Yes' has a higher peak around lower Monthly Income
# Whereas, the distribution of 'Attrition = No' is comparatively dense around higher income levels

# %%
# Attrition by Department

fig, ax = plt.subplots(1,2)

fig.subplots_adjust(wspace=1)


sns.countplot(df_attrition_n['Department'], ax=ax[0])
ax[0].set_title('Attrition = No')
plt.setp(ax[0].get_xticklabels(), rotation=90, ha="center")

sns.countplot(df_attrition_y['Department'], ax=ax[1])
ax[1].set_title('Attrition = Yes')
plt.setp(ax[1].get_xticklabels(), rotation=90, ha="center")
# Out:
# [None, None, None, None, None, None]

# %%
# The proportion of employees from sales department seems to be higher among those who discontinued

# %%
# Income levels by gender and marital status

fig, ax = plt.subplots(1,2)
fig.subplots_adjust(wspace=1)

sns.boxplot(x='Gender', y='MonthlyIncome', data=df_hr, ax=ax[0])
sns.boxplot(x='MaritalStatus', y='MonthlyIncome', data=df_hr, ax=ax[1])

# %%
# Male and Female have similar income levels
# Single employees have lower income than married and divorced; 
    # probably because single employees are in the initial stage of their careers

# %%
# Income levels by Education Field and Job Role

fig, ax = plt.subplots(2,1)
fig.subplots_adjust(hspace=0.33)

sns.boxplot(x='MonthlyIncome', y='EducationField', data=df_hr, ax=ax[0])
sns.boxplot(x='MonthlyIncome', y='JobRole', data=df_hr, ax=ax[1])

# %%
# Employees from different education fields seem to have similar income levels
# Nonetheless, it can be noted that employees from Life Sciences and Medical background have more number of outliers

# Research Director and Manager have the highest income levels
# Research Scientist, Laboratory Technician, and Sales Representatives have lowest income levels

# %%
# Models
# We will compare the Execution Time and Accuracy of the models without PCA with those of the models with PCA

# Without and With PCA
    # Logistic Regression
    # Decision Tree
    # K Nearest Neighbors
    # Naive Bayes Classifier
    # SVM Classifier

# %%
# Converting categorical variables into dummy variables

df_dummy = pd.get_dummies(df_hr, drop_first=True)
df_dummy.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                4  ...                              0                0
# 1                2  ...                              0                0
# ...

# %%
# Creating Target and Input variables

df_hr_model = df_dummy

y = df_hr_model['Attrition']
X = df_hr_model.drop('Attrition', axis=1, inplace=False)

# %%
# Scaling the continuous variables using StandardScaler
# However, we will not scale the ordinal features - as applying StandardScaler can produce udesired results

from sklearn.preprocessing import StandardScaler

X_scaled = X.copy()

col_names = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome',  
                                          'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
                                          'TotalWorkingYears', 'TrainingTimesLastYear', 
                                          'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 
                                          'YearsWithCurrManager']

features = X_scaled[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

X_scaled[col_names] = features
X_scaled.head()
# Out:
# C:\Users\nikhi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\nikhi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
#         Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0  0.446350   0.742527         -1.010909          2                        2
# 1  1.322365  -1.297775         -0.147150          1                        3
# 2  0.008343   1.414363         -0.887515          2                        4
# 3 -0.429664   1.461466         -0.764121          4                        4
# 4 -1.086676  -0.524295         -0.887515          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# ...

# %%
# Splitting the data into train and test datasets
# Test will 30% of the original dataframe

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=0)

# %%
# Models without PCA

# %%
# Logistic Regression without PCA

from sklearn.linear_model import LogisticRegression

import time
start = time.time()

logreg = LogisticRegression()
logreg.fit(X_train,y_train)

end = time.time()
logreg_time = end-start
print('Train Time (seconds) of Logistic Regression without PCA:',logreg_time)
# Out:
# Train Time (seconds) of Logistic Regression without PCA: 0.02464151382446289
# C:\Users\nikhi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_pred_logreg = logreg.predict(X_test)

logreg_roc_auc = roc_auc_score(y_test,y_pred_logreg)
fpr, tpr, thresholds = roc_curve(y_test,logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (Area = %0.2f)' % logreg_roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_logreg = confusion_matrix(y_test,y_pred_logreg)
print("\nConfusion Matrix")
print(confusion_matrix_logreg)

classify_logreg = classification_report(y_test, y_pred_logreg)
print("\nClassification Report")
print(classify_logreg)
# Out:
# Confusion Matrix
# [[363   8]
#  [ 39  31]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       371
#            1       0.79      0.44      0.57        70
#
#    micro avg       0.89      0.89      0.89       441
#    macro avg       0.85      0.71      0.75       441
# weighted avg       0.89      0.89      0.88       441

# %%
# Decision Tree without PCA

from sklearn.tree import DecisionTreeClassifier

start = time.time()

dectree = DecisionTreeClassifier()
dectree.fit(X_train,y_train)

end = time.time()
dectree_time = end-start
print('Train Time (seconds) of Decision Tree without PCA:',dectree_time)
# Out:
# Train Time (seconds) of Decision Tree without PCA: 0.021703243255615234

# %%
y_pred_dectree = dectree.predict(X_test)

dectree_roc_auc = roc_auc_score(y_test,y_pred_logreg)
fpr, tpr, thresholds = roc_curve(y_test,dectree.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Decision Tree (Area = %0.2f)' % dectree_roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_dectree = confusion_matrix(y_test,y_pred_dectree)
print("\nConfusion Matrix")
print(confusion_matrix_dectree)

classify_dectree = classification_report(y_test, y_pred_dectree)
print("\nClassification Report")
print(classify_dectree)
# Out:
# Confusion Matrix
# [[323  48]
#  [ 45  25]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       371
#            1       0.34      0.36      0.35        70
#
#    micro avg       0.79      0.79      0.79       441
#    macro avg       0.61      0.61      0.61       441
# weighted avg       0.79      0.79      0.79       441

# %%
# Number of nodes and depth of decision tree without PCA

n_nodes = dectree.tree_.node_count
n_nodes

depth = dectree.tree_.max_depth
depth

print('Decision Tree without PCA')
print('Nodes:',n_nodes)
print('Depth:',depth)
# Out:
# Decision Tree without PCA
# Nodes: 237
# Depth: 14

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dectree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
# K Nearest Neighbors Classifier without PCA

from sklearn.neighbors import KNeighborsClassifier

neighbors = np.arange(1,11)
train_accuracy =np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))


for i,k in enumerate(neighbors):
    #Setup a knn classifier with k neighbors
    knn = KNeighborsClassifier(n_neighbors=k)
    
    #Fit the model
    knn.fit(X_train, y_train)
    
    #Compute accuracy on the training set
    train_accuracy[i] = knn.score(X_train, y_train)
    
    #Compute accuracy on the test set
    test_accuracy[i] = knn.score(X_test, y_test)

# %%
# Using test accuracy to find the number of neighbors

plt.title('k-NN Accuracy for different number of neighbors')
plt.plot(neighbors, test_accuracy, label='Testing Accuracy')
plt.plot(neighbors, train_accuracy, label='Training accuracy')
plt.legend()
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy')
plt.show()

# %%
# The test accuracy is maximum for n = 9

# %%
start = time.time()

knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train, y_train)

end = time.time()
knn_time = end-start
print('Train Time (seconds) of KNN without PCA:',knn_time)
# Out:
# Train Time (seconds) of KNN without PCA: 0.008826971054077148

# %%
y_pred_knn = knn.predict(X_test)

knn_roc_auc = roc_auc_score(y_test,y_pred_knn)
fpr, tpr, thresholds = roc_curve(y_test,knn.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNN (Area = %0.2f)' % knn_roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_knn = confusion_matrix(y_test,y_pred_knn)
print("\nConfusion Matrix")
print(confusion_matrix_knn)

classify_knn = classification_report(y_test, y_pred_knn)
print("\nClassification Report")
print(classify_knn)
# Out:
# Confusion Matrix
# [[371   0]
#  [ 61   9]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       371
#            1       1.00      0.13      0.23        70
#
#    micro avg       0.86      0.86      0.86       441
#    macro avg       0.93      0.56      0.58       441
# weighted avg       0.88      0.86      0.81       441

# %%
# Naive Bayes Classifier withuot PCA

from sklearn.naive_bayes import GaussianNB

start = time.time()

nb = GaussianNB()
nb.fit(X_train,y_train)

end = time.time()
nb_time = end-start
print('Train Time (seconds) of Naive Bayes without PCA:',nb_time)
# Out:
# Train Time (seconds) of Naive Bayes without PCA: 0.007591962814331055

# %%
y_pred_nb = nb.predict(X_test)

nb_roc_auc = roc_auc_score(y_test,y_pred_nb)
fpr, tpr, thresholds = roc_curve(y_test,nb.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Naive Bayes (Area = %0.2f)' % nb_roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_nb = confusion_matrix(y_test,y_pred_nb)
print("\nConfusion Matrix")
print(confusion_matrix_nb)

classify_nb = classification_report(y_test, y_pred_nb)
print("\nClassification Report")
print(classify_nb)
# Out:
# Confusion Matrix
# [[224 147]
#  [ 19  51]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.60      0.73       371
#            1       0.26      0.73      0.38        70
#
#    micro avg       0.62      0.62      0.62       441
#    macro avg       0.59      0.67      0.56       441
# weighted avg       0.82      0.62      0.67       441

# %%
# SVM Classifier without PCA

from sklearn.svm import SVC

start = time.time()

svc = SVC(kernel = 'rbf', probability = True)
svc.fit(X_train, y_train)

end = time.time()
svm_time = end-start
print('Train Time (seconds) of SVM without PCA:',svm_time)
# Out:
# C:\Users\nikhi\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Train Time (seconds) of SVM without PCA: 0.2512533664703369

# %%
y_pred_svc = svc.predict(X_test)

svc_roc_auc = roc_auc_score(y_test,y_pred_svc)
fpr, tpr, thresholds = roc_curve(y_test,svc.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='SVM (Area = %0.2f)' % svc_roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_svc = confusion_matrix(y_test,y_pred_svc)
print("\nConfusion Matrix")
print(confusion_matrix_svc)

classify_svc = classification_report(y_test, y_pred_svc)
print("\nClassification Report")
print(classify_svc)
# Out:
# Confusion Matrix
# [[370   1]
#  [ 59  11]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       371
#            1       0.92      0.16      0.27        70
#
#    micro avg       0.86      0.86      0.86       441
#    macro avg       0.89      0.58      0.60       441
# weighted avg       0.87      0.86      0.82       441

# %%
# Principal Component Analysis

# We have an option of deciding the number of components we need in the output
# However, we will rather specify the minimum variation we want to be retained
    # Thus, we will let the model provide us the number of components

# %%
from sklearn.decomposition import PCA

# Make an instance of the model and specify that 90% of the variance needs to be retained
n = 90
pca = PCA(n/100)

# Fit the PCA on the training set
pca.fit(X_train)

print('To retain',n,'% of the variation, we needed',pca.n_components_,'components')
# Out:
# To retain 90 % of the variation, we needed 21 components

# %%
# Applying transformation to both Training and Test set

X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
# Logistic Regression with PCA

start = time.time()

logreg_pca = LogisticRegression()
logreg_pca.fit(X_train_pca,y_train)

end = time.time()
logreg_time_pca = end-start
print('Train Time (seconds) of Logistic Regression with PCA:',logreg_time_pca)
# Out:
# Train Time (seconds) of Logistic Regression with PCA: 0.004372596740722656
# C:\Users\nikhi\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
y_pred_logreg_pca = logreg_pca.predict(X_test_pca)

logreg_roc_auc_pca = roc_auc_score(y_test,y_pred_logreg_pca)
fpr, tpr, thresholds = roc_curve(y_test,logreg_pca.predict_proba(X_test_pca)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (Area = %0.2f)' % logreg_roc_auc_pca)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_logreg_pca = confusion_matrix(y_test,y_pred_logreg_pca)
print("\nConfusion Matrix")
print(confusion_matrix_logreg_pca)

classify_logreg_pca = classification_report(y_test, y_pred_logreg_pca)
print("\nClassification Report")
print(classify_logreg_pca)
# Out:
# Confusion Matrix
# [[365   6]
#  [ 56  14]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       371
#            1       0.70      0.20      0.31        70
#
#    micro avg       0.86      0.86      0.86       441
#    macro avg       0.78      0.59      0.62       441
# weighted avg       0.84      0.86      0.82       441

# %%
# Decision Tree with PCA

start = time.time()

dectree_pca = DecisionTreeClassifier()
dectree_pca.fit(X_train_pca,y_train)

end = time.time()
dectree_time_pca = end-start
print('Train Time (seconds) of Decision Tree with PCA:',dectree_time_pca)
# Out:
# Train Time (seconds) of Decision Tree with PCA: 0.03761744499206543

# %%
y_pred_dectree_pca = dectree_pca.predict(X_test_pca)

dectree_roc_auc_pca = roc_auc_score(y_test,y_pred_dectree_pca)
fpr, tpr, thresholds = roc_curve(y_test,dectree_pca.predict_proba(X_test_pca)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Decision Tree (Area = %0.2f)' % dectree_roc_auc_pca)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_dectree_pca = confusion_matrix(y_test,y_pred_dectree_pca)
print("\nConfusion Matrix")
print(confusion_matrix_dectree_pca)

classify_dectree_pca = classification_report(y_test, y_pred_dectree_pca)
print("\nClassification Report")
print(classify_dectree_pca)
# Out:
# Confusion Matrix
# [[316  55]
#  [ 51  19]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       371
#            1       0.26      0.27      0.26        70
#
#    micro avg       0.76      0.76      0.76       441
#    macro avg       0.56      0.56      0.56       441
# weighted avg       0.77      0.76      0.76       441

# %%
# Number of nodes and depth of decision tree with PCA

n_nodes_pca = dectree_pca.tree_.node_count
n_nodes_pca

depth_pca = dectree_pca.tree_.max_depth
depth_pca

print('Decision Tree after PCA')
print('Nodes:',n_nodes_pca)
print('Depth:',depth_pca)
# Out:
# Decision Tree after PCA
# Nodes: 227
# Depth: 23

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dectree_pca, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
# K Nearest Neighbors Classifier with PCA
# As previously we used n=9, we will use the same n here

start = time.time()

knn_pca = KNeighborsClassifier(n_neighbors=9)
knn_pca.fit(X_train_pca, y_train)

end = time.time()
knn_time_pca = end-start
print('Train Time (seconds) of KNN with PCA:',knn_time_pca)
# Out:
# Train Time (seconds) of KNN with PCA: 0.005181312561035156

# %%
y_pred_knn_pca = knn_pca.predict(X_test_pca)

knn_roc_auc_pca = roc_auc_score(y_test,y_pred_knn_pca)
fpr, tpr, thresholds = roc_curve(y_test,knn_pca.predict_proba(X_test_pca)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNN (Area = %0.2f)' % knn_roc_auc_pca)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_knn_pca = confusion_matrix(y_test,y_pred_knn_pca)
print("\nConfusion Matrix")
print(confusion_matrix_knn_pca)

classify_knn_pca = classification_report(y_test, y_pred_knn_pca)
print("\nClassification Report")
print(classify_knn_pca)
# Out:
# Confusion Matrix
# [[368   3]
#  [ 66   4]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       371
#            1       0.57      0.06      0.10        70
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.71      0.52      0.51       441
# weighted avg       0.80      0.84      0.79       441

# %%
# Naive Bayes Classifier with PCA

start = time.time()

nb_pca = GaussianNB()
nb_pca.fit(X_train_pca,y_train)

end = time.time()
nb_time_pca = end-start
print('Train Time (seconds) of Naive Bayes with PCA:',nb_time_pca)
# Out:
# Train Time (seconds) of Naive Bayes with PCA: 0.0035445690155029297

# %%
y_pred_nb_pca = nb_pca.predict(X_test_pca)

nb_roc_auc_pca = roc_auc_score(y_test,y_pred_nb_pca)
fpr, tpr, thresholds = roc_curve(y_test,nb_pca.predict_proba(X_test_pca)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Naive Bayes (Area = %0.2f)' % nb_roc_auc_pca)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_nb_pca = confusion_matrix(y_test,y_pred_nb_pca)
print("\nConfusion Matrix")
print(confusion_matrix_nb_pca)

classify_nb_pca = classification_report(y_test, y_pred_nb_pca)
print("\nClassification Report")
print(classify_nb_pca)
# Out:
# Confusion Matrix
# [[367   4]
#  [ 51  19]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       371
#            1       0.83      0.27      0.41        70
#
#    micro avg       0.88      0.88      0.88       441
#    macro avg       0.85      0.63      0.67       441
# weighted avg       0.87      0.88      0.85       441

# %%
# SVM with PCA

start = time.time()

svc_pca = SVC(kernel = 'rbf', probability = True)
svc_pca.fit(X_train_pca, y_train)

end = time.time()
svm_time_pca = end-start
print('Train Time (seconds) of SVM with PCA:',svm_time_pca)
# Out:
# C:\Users\nikhi\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Train Time (seconds) of SVM with PCA: 0.21158218383789062

# %%
y_pred_svc_pca = svc_pca.predict(X_test_pca)

svc_roc_auc_pca = roc_auc_score(y_test,y_pred_svc_pca)
fpr, tpr, thresholds = roc_curve(y_test,svc_pca.predict_proba(X_test_pca)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='SVM (Area = %0.2f)' % svc_roc_auc_pca)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Fasle Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

confusion_matrix_svc_pca = confusion_matrix(y_test,y_pred_svc_pca)
print("\nConfusion Matrix")
print(confusion_matrix_svc_pca)

classify_svc_pca = classification_report(y_test, y_pred_svc_pca)
print("\nClassification Report")
print(classify_svc_pca)
# Out:
# Confusion Matrix
# [[369   2]
#  [ 61   9]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       371
#            1       0.82      0.13      0.22        70
#
#    micro avg       0.86      0.86      0.86       441
#    macro avg       0.84      0.56      0.57       441
# weighted avg       0.85      0.86      0.81       441

# %%
accuracy = {'Model': ['Logistic Regression', 'Decision Tree', 'K Nearest Neighbors', 'Naive Bayes', 'SVM'], 
               'Accuracy - no PCA (%)': [89, 79, 86, 62, 86], 
               'Accuracy - PCA (%)': [86, 76, 84, 88, 86]
              }



acc = pd.DataFrame(data=accuracy)

acc
# Out:
#                  Model  Accuracy - no PCA (%)  Accuracy - PCA (%)
# 0  Logistic Regression                     89                  86
# 1        Decision Tree                     79                  76
# 2  K Nearest Neighbors                     86                  84
# 3          Naive Bayes                     62                  88
# 4                  SVM                     86                  86

# %%
acc = acc.set_index('Model')

# %%
sns.set_style(style='white')
ax = acc.plot(kind='bar', figsize=(20,8), width=0.4, color=['#42b3d5', '#e85285'], fontsize=18)

ax.legend(loc='best')
plt.xticks(rotation=0, ha="center")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(False)
ax.spines['left'].set_linewidth(False)

ax.yaxis.grid()
ax.get_yaxis().set_visible(False)
plt.title('Impact of PCA on Accuracy (%)', fontsize=20)

for n in range(2):
    for index, val in enumerate(acc.iloc[:,n].transpose()): 
        label=str(val) + '%'
        
        if n==0:
            ax.annotate(label, xy=(index-0.15, val-5), color='#ffffff', fontsize=14, fontweight='bold')
        elif n==1:
            ax.annotate(label, xy=(index+0.05, val-5), color='#ffffff', fontsize=14, fontweight='bold')

plt.show()

# %%
# In Logistic Regression, Decision Tree, and KNN accuracy decreases slightly after PCA
# In Naive Bayes, accuracy increases significantly after PCA
# IN SVM, accuracy remains same

# %%
time = {'Model': ['Logistic Regression', 'Decision Tree', 'K Nearest Neighbors', 'Naive Bayes', 'SVM'],
                  'Train Time - no PCA (s) ': [logreg_time, dectree_time, knn_time, nb_time, svm_time],
                  'Train Time - PCA (s) ': [logreg_time_pca, dectree_time_pca, knn_time_pca, nb_time_pca, svm_time_pca]
               }


tm = pd.DataFrame(data=time)
tm
# Out:
#                  Model  Train Time - no PCA (s)   Train Time - PCA (s)
# 0  Logistic Regression                  0.024642               0.004373
# 1        Decision Tree                  0.021703               0.037617
# 2  K Nearest Neighbors                  0.008827               0.005181
# 3          Naive Bayes                  0.007592               0.003545
# 4                  SVM                  0.251253               0.211582

# %%
tm = tm.set_index('Model')

# %%
sns.set_style(style='white')

ax = tm.plot(kind='bar', figsize=(20,8), width=0.6, color=['#9932CC', '#76EE00'], fontsize=18)

ax.legend(loc='best')
plt.xticks(rotation=0, ha="center")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(False)
ax.spines['left'].set_linewidth(False)
ax.yaxis.grid()
ax.get_yaxis().set_visible(False)
plt.title('Impact of PCA on Train Time (Seconds)', fontsize=20)


for n in range(2):
    for index, val in enumerate(tm.iloc[:,n].transpose()): 
        label=str(round(val,4))
        
        if n==0:
            ax.annotate(label, xy=(index-0.25, val+0.007), color='#9932CC', fontsize=14, fontweight='bold')
        elif n==1:
            ax.annotate(label, xy=(index+0.05, val+0.007), color='#76EE00', fontsize=14, fontweight='bold')

# %%
# In Logistic Regression, KNN, Naive Bayes, and SVM, Train Time decreased after PCA
# In Decision Tree, Train Time increases significantly after PCA
